# %%
# LOAD LIBS AND MAGIC STUFF
# %load_ext sql
# %sql postgresql+psycopg2://postgres:admin@10.0.0.57:37020/aiup26

# %%
# Write and execute a SQL query to list the school names, community names and average attendance for communities with a hardship index of 98.
# %sql select cps.name_of_school, cps.community_area_name, cps.average_teacher_attendance, cps.average_student_attendance from chicago_public_schools cps LEFT JOIN census_data cd ON cps.community_area_number = cd.community_area_number WHERE cd.hardship_index = 98
# Out:
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# 4 rows affected.
# [('Ira F Aldridge Elementary School', 'RIVERDALE', Decimal('96.3'), Decimal('92.9')),
#  ('George Washington Carver Military Academy High School', 'RIVERDALE', Decimal('96.4'), Decimal('91.6')),
#  ('George Washington Carver Primary School', 'RIVERDALE', Decimal('94.7'), Decimal('90.9')),
#  ('William E B Dubois Elementary School', 'RIVERDALE', Decimal('94.4'), Decimal('93.3'))]

# %%
# Write and execute a SQL query to list all crimes that took place at a school. Include case number, crime type and community name
# %sql select c.case_number, c.primary_type, s.community_area_name from chicago_crime_data as c LEFT JOIN chicago_public_schools as s on c.community_area_number = s.community_area_number WHERE LOWER(c.location_description) like '%school%'
# Out:
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# 116 rows affected.
# [('HL725506', 'BATTERY', 'LINCOLN SQUARE'),
#  ('HT315369', 'ASSAULT', 'EAST GARFIELD PARK'),
#  ('HS305355', 'NARCOTICS', 'BRIGHTON PARK'),
#  ('HR585012', 'CRIMINAL TRESPASS', 'ASHBURN'),
#  ('JA460432', 'BATTERY', 'ASHBURN'),
#  ('HL353697', 'BATTERY', 'SOUTH SHORE'),
#  ('HS200939', 'CRIMINAL DAMAGE', 'AUSTIN'),
#  ('HH639427', 'BATTERY', 'AUSTIN'),
#  ('HT315369', 'ASSAULT', 'EAST GARFIELD PARK'),
#  ('HT315369', 'ASSAULT', 'EAST GARFIELD PARK'),
#  ('HR585012', 'CRIMINAL TRESPASS', 'ASHBURN'),
#  ('JA460432', 'BATTERY', 'ASHBURN'),
#  ('HS200939', 'CRIMINAL DAMAGE', 'AUSTIN'),
#  ('HH639427', 'BATTERY', 'AUSTIN'),
#  ('HP716225', 'BATTERY', 'DOUGLAS'),
#  ('HS200939', 'CRIMINAL DAMAGE', 'AUSTIN'),
#  ('HH639427', 'BATTERY', 'AUSTIN'),
#  ('HS200939', 'CRIMINAL DAMAGE', 'AUSTIN'),
#  ('HH639427', 'BATTERY', 'AUSTIN'),
#  ('HT315369', 'ASSAULT', 'EAST GARFIELD PARK'),
# ...

# %%
# Write and execute a SQL statement to create a view showing the columns listed in the following table, with new column names as shown in the second column.
# %sql drop view PUBLIC_SCHOOLS
# %sql CREATE VIEW PUBLIC_SCHOOLS (School_Name, Safety_Rating, Family_Rating, Environment_Rating, Instruction_Rating, Leaders_Rating, Teachers_Rating) AS SELECT NAME_OF_SCHOOL, Safety_Icon, family_involvement_icon, environment_icon, instruction_icon, leaders_icon, Teachers_Icon FROM chicago_public_schools

# Write and execute a SQL statement that returns all of the columns from the view.
# %sql select * from public_schools

# Write and execute a SQL statement that returns just the school name and leaders rating from the view.
# %sql select School_Name, Leaders_Rating from public_schools
# Out:
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# (psycopg2.errors.UndefinedTable) view "public_schools" does not exist
#
# [SQL: drop view PUBLIC_SCHOOLS]
# (Background on this error at: https://sqlalche.me/e/14/f405)
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# Done.
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# 566 rows affected.
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# 566 rows affected.
# [('Charles G Hammond Elementary School', 'NDA'),
#  ('Marvin Camras Elementary School', 'Very Strong'),
#  ('Eliza Chappell Elementary School', 'Average'),
#  ('Daniel R Cameron Elementary School', 'NDA'),
#  ('Sir Miles Davis Magnet Elementary Academy', 'NDA'),
#  ('Luther Burbank Elementary School', 'NDA'),
#  ('Lenart Elementary Regional Gifted Center', 'Average'),
#  ('James N Thorp Elementary School', 'NDA'),
#  ('Walter Payton College Preparatory High School', 'NDA'),
# ...
