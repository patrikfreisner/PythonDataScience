# %%
# LOAD LIBS AND MAGIC STUFF
# %load_ext sql
# %sql postgresql+psycopg2://postgres:admin@10.0.0.57:37020/aiup26

# %%
# %sql DROP VIEW community_crimes
# %sql CREATE VIEW COMMUNITY_CRIMES AS select community_area_number, count(*) as Number_of_Crime from CHICAGO_CRIME_DATA where community_area_number is not NULL group by community_area_number order by number_of_crime desc
# Out:
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# Done.
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# Done.
# []

# %%
# %sql SELECT cd.community_area_name, cc.number_of_crime FROM community_crimes cc, census_data cd WHERE cc.community_area_number = cd.community_area_number
# Out:
#  * postgresql+psycopg2://postgres:***@10.0.0.57:37020/aiup26
# 70 rows affected.
# [('Rogers Park', 6),
#  ('West Ridge', 7),
#  ('Uptown', 4),
#  ('Lincoln Square', 3),
#  ('North Center', 4),
#  ('Lake View', 11),
#  ('Lincoln Park', 5),
#  ('Near North Side', 15),
#  ('Norwood Park', 3),
#  ('Jefferson Park', 2),
#  ('Forest Glen', 1),
#  ('Albany Park', 5),
#  ('Portage Park', 5),
#  ('Irving Park', 8),
#  ('Dunning', 3),
#  ('Montclaire', 2),
#  ('Belmont Cragin', 8),
#  ('Hermosa', 3),
#  ('Avondale', 6),
#  ('Logan Square', 9),
#  ('Humboldt park', 22),
#  ('West Town', 13),
#  ('Austin', 43),
#  ('West Garfield Park', 10),
#  ('East Garfield Park', 8),
#  ('Near West Side', 16),
#  ('North Lawndale', 16),
#  ('South Lawndale', 8),
#  ('Lower West Side', 9),
#  ('Loop', 7),
#  ('Near South Side', 1),
#  ('Douglas', 5),
#  ('Fuller Park', 2),
#  ('Grand Boulevard', 8),
#  ('Kenwood', 4),
#  ('Hyde Park', 2),
#  ('Woodlawn', 8),
#  ('South Shore', 9),
#  ('Chatham', 8),
# ...

# %%
# -- INNER JOIN GET WHAT MATCHES
# -- OUTER JOIN GET WHAT MATCHES AND WHAT DOESN'T
